# %%
import pandas as pd

# %%
# !conda install pandas
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# ...
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# done
# Solving environment: /
# -
# \
# done
# # All requested packages already installed.

# %%
df = pd.read_csv('https://bit.ly/664-met-woman')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 59 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             500 non-null    int64
#  1   objectID               492 non-null    float64
#  2   isHighlight            492 non-null    float64
#  3   accessionNumber        492 non-null    object
#  4   accessionYear          489 non-null    float64
#  5   isPublicDomain         492 non-null    float64
#  6   primaryImage           415 non-null    object
#  7   primaryImageSmall      415 non-null    object
#  8   additionalImages       492 non-null    object
#  9   constituents           129 non-null    object
#  10  department             492 non-null    object
#  11  objectName             491 non-null    object
#  12  title                  492 non-null    object
#  13  culture                283 non-null    object
# ...

# %%
df.shape
# Out:
# (500, 59)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'objectID', 'isHighlight', 'accessionNumber',
#        'accessionYear', 'isPublicDomain', 'primaryImage', 'primaryImageSmall',
#        'additionalImages', 'constituents', 'department', 'objectName', 'title',
#        'culture', 'period', 'dynasty', 'reign', 'portfolio', 'artistRole',
#        'artistPrefix', 'artistDisplayName', 'artistDisplayBio', 'artistSuffix',
#        'artistAlphaSort', 'artistNationality', 'artistBeginDate',
#        'artistEndDate', 'artistGender', 'artistWikidata_URL', 'artistULAN_URL',
#        'objectDate', 'objectBeginDate', 'objectEndDate', 'medium',
#        'dimensions', 'measurements', 'creditLine', 'geographyType', 'city',
#        'state', 'county', 'country', 'region', 'subregion', 'locale', 'locus',
#        'excavation', 'river', 'classification', 'rightsAndReproduction',
#        'linkResource', 'metadataDate', 'repository', 'objectURL', 'tags',
#        'objectWikidata_URL', 'isTimelineWork', 'GalleryNumber', 'message'],
# ...

# %%
df['title']
# Out:
# 0                                                  Woman
# 1                                                  Woman
# 2                        Terracotta lekythos (oil flask)
# 3                                                  Woman
# 4                                                  Woman
#                              ...
# 495                          Abduction of a Sabine Woman
# 496                Susannah and the Elders before Daniel
# 497    Terracotta alabastron (perfume vase) in the fo...
# 498                                            Sa Amulet
# 499                                      The Thrown Kiss
# Name: title, Length: 500, dtype: object

# %%
df.iloc[495].get('objectURL')
# Out:
# 'https://www.metmuseum.org/art/collection/search/202972'

# %%
df['artistDisplayName']
# Out:
# 0                        Willem de Kooning
# 1      Royal Porcelain Manufactory, Naples
# 2                            Woman Painter
# 3                                  Man Ray
# 4                        Willem de Kooning
#                       ...
# 495                            Giambologna
# 496                       Pomponio Amalteo
# 497                                    NaN
# 498                                    NaN
# 499                    Meissen Manufactory
# Name: artistDisplayName, Length: 500, dtype: object

# %%
df['country'].values
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Mali', nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'Egypt', 'Egypt', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, 'Egypt', nan, nan, nan, nan, nan, nan, nan,
#        'Egypt', 'Egypt', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'France', nan, nan, 'Turkey', nan, nan, 'Byzantine Egypt', 'Egypt',
#        nan, nan, 'Egypt', nan, nan, 'Egypt', nan, 'Egypt', 'Egypt', nan,
#        nan, nan, nan, nan, nan, 'Egypt', nan, nan, 'Egypt', 'Egypt', nan,
#        'Egypt', 'Egypt', nan, 'Egypt', 'Egypt', nan, 'Egypt', nan,
#        'Egypt', 'Egypt', 'Egypt', nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'German', nan,
#        nan, 'Egypt', nan, nan, nan, nan, nan, nan, 'Iran', nan, nan, nan,
#        nan, nan, nan, nan, nan, 'Egypt', nan, nan, 'Egypt', nan, nan,
# ...

# %%
# .info(), .head(), .tail(), columns, shape
# .values(), .iloc(), slicing rows

# %%
# sorting values and counting values
# .value_counts(), sort_values()

df['artistDisplayName'].value_counts()
# Out:
# artistDisplayName
# Edgar Degas                                       14
# Imperial Porcelain Manufactory, St. Petersburg     8
# Pablo Picasso                                      7
# Willem de Kooning                                  3
# Joan Miró                                          3
#                                                   ..
# Berthe Morisot                                     1
# Antoine Watteau                                    1
# Orazio Borgianni                                   1
# Georges Braque                                     1
# Pomponio Amalteo                                   1
# Name: count, Length: 90, dtype: int64

# %%
df['title'].value_counts()
# Out:
# title
# Terracotta statuette of a woman               31
# Woman                                         20
# Terracotta head of a woman                    18
# Terracotta statuette of a draped woman         9
# Portrait of a Woman                            9
#                                               ..
# Chair for a Woman                              1
# Relief Fragment Depicting a Kneeling Woman     1
# Statuette of a woman ?                         1
# Terracotta seated veiled woman                 1
# The Thrown Kiss                                1
# Name: count, Length: 332, dtype: int64

# %%
df['title'].sort_values()
# Out:
# 89                               A Goldsmith in his Shop
# 122                                        A Royal Woman
# 286                                      A Woman Ironing
# 274                                      A Woman Reading
# 35     A Woman Seated beside a Vase of Flowers (Madam...
#                              ...
# 24                                                   NaN
# 353                                                  NaN
# 356                                                  NaN
# 427                                                  NaN
# 472                                                  NaN
# Name: title, Length: 500, dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'objectID', 'isHighlight', 'accessionNumber',
#        'accessionYear', 'isPublicDomain', 'primaryImage', 'primaryImageSmall',
#        'additionalImages', 'constituents', 'department', 'objectName', 'title',
#        'culture', 'period', 'dynasty', 'reign', 'portfolio', 'artistRole',
#        'artistPrefix', 'artistDisplayName', 'artistDisplayBio', 'artistSuffix',
#        'artistAlphaSort', 'artistNationality', 'artistBeginDate',
#        'artistEndDate', 'artistGender', 'artistWikidata_URL', 'artistULAN_URL',
#        'objectDate', 'objectBeginDate', 'objectEndDate', 'medium',
#        'dimensions', 'measurements', 'creditLine', 'geographyType', 'city',
#        'state', 'county', 'country', 'region', 'subregion', 'locale', 'locus',
#        'excavation', 'river', 'classification', 'rightsAndReproduction',
#        'linkResource', 'metadataDate', 'repository', 'objectURL', 'tags',
#        'objectWikidata_URL', 'isTimelineWork', 'GalleryNumber', 'message'],
# ...

# %%
df['accessionYear'].sort_values()
# Out:
# 467    1871.0
# 110    1874.0
# 341    1874.0
# 217    1874.0
# 334    1874.0
#         ...
# 353       NaN
# 356       NaN
# 367       NaN
# 427       NaN
# 472       NaN
# Name: accessionYear, Length: 500, dtype: float64

# %%
df['accessionYear'].sort_values()
# Out:
# 467    1871.0
# 110    1874.0
# 341    1874.0
# 217    1874.0
# 334    1874.0
#         ...
# 353       NaN
# 356       NaN
# 367       NaN
# 427       NaN
# 472       NaN
# Name: accessionYear, Length: 500, dtype: float64

# %%
by_year = df.sort_values('accessionYear')

# %%
by_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 467 to 472
# Data columns (total 59 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             500 non-null    int64
#  1   objectID               492 non-null    float64
#  2   isHighlight            492 non-null    float64
#  3   accessionNumber        492 non-null    object
#  4   accessionYear          489 non-null    float64
#  5   isPublicDomain         492 non-null    float64
#  6   primaryImage           415 non-null    object
#  7   primaryImageSmall      415 non-null    object
#  8   additionalImages       492 non-null    object
#  9   constituents           129 non-null    object
#  10  department             492 non-null    object
#  11  objectName             491 non-null    object
#  12  title                  492 non-null    object
#  13  culture                283 non-null    object
# ...

# %%
highlights = df['isHighlight'] == 1.0

# %%
df[highlights].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 22 to 461
# Data columns (total 59 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             37 non-null     int64
#  1   objectID               37 non-null     float64
#  2   isHighlight            37 non-null     float64
#  3   accessionNumber        37 non-null     object
#  4   accessionYear          37 non-null     float64
#  5   isPublicDomain         37 non-null     float64
#  6   primaryImage           29 non-null     object
#  7   primaryImageSmall      29 non-null     object
#  8   additionalImages       37 non-null     object
#  9   constituents           19 non-null     object
#  10  department             37 non-null     object
#  11  objectName             37 non-null     object
#  12  title                  37 non-null     object
#  13  culture                14 non-null     object
# ...

# %%
df.iloc[461]['objectURL']
# Out:
# 'https://www.metmuseum.org/art/collection/search/271716'

# %%
# .str.contains()

courbet = df['artistDisplayName'].str.contains('Courbet', na = False)

# %%
# write a str.contains statement to check if the title has a specific word
# create a new dataframe from the results

old = df['title'].str.contains('old', na=False)

# %%
df[old]['objectURL'].iloc[0]
# Out:
# 'https://www.metmuseum.org/art/collection/search/548584'

# %%
df[old]['objectURL'].iloc[2]
# Out:
# 'https://www.metmuseum.org/art/collection/search/248132'

# %%
df = pd.read_csv('https://bit.ly/anti-trans-tracker-csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   State                         674 non-null    object
#  1   Number                        674 non-null    object
#  2   Summary                       673 non-null    object
#  3   Bill Type                     674 non-null    object
#  4   Date                          674 non-null    object
#  5   Status                        674 non-null    object
#  6   Youth State Risk              674 non-null    object
#  7   Adult State Risk              674 non-null    object
#  8   Notes                         365 non-null    object
#  9   URL                           674 non-null    object
#  10  Sponsors                      530 non-null    object
#  11  Calendar                      255 non-null    object
# ...

# %%
df['Bill Type'].value_counts()
# Out:
# Bill Type
# Online Obscenity Law                                          86
# Gender Affirming Care Ban                                     61
# Book Ban                                                      51
# Sports Ban                                                    43
# DEI Ban                                                       40
#                                                               ..
# Forced Outing By Schools/ Trans Bathroom Ban                   1
# Trans Bathroom Ban/ Sports Ban                                 1
# Anti-Journalism                                                1
# Gender Affirming Care Ban/ Sports Ban / Child Custody Bill     1
# Book Ban / Legal Discrimination in Education / Obscenity       1
# Name: count, Length: 83, dtype: int64

# %%
df['Bill Type'] == 'Book Ban'
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 669     True
# 670    False
# 671    False
# 672    False
# 673    False
# Name: Bill Type, Length: 674, dtype: bool

# %%
bans = df['Bill Type'] == 'Book Ban'

# %%
import matplotlib

# %%
df[bans].value_counts('State').plot(kind = 'bar')
# Out:
# <Axes: xlabel='State'>

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['State'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Bill Type'].values
# Out:
# array(['End Legal Recognition', 'Book Ban', "Don't Say Gay Expansion",
#        'Online Obscenity Law', 'Online Obscenity Law', 'Drag Ban',
#        'Book Ban', 'DEI Ban / Trans Bathroom Ban', 'Pride Flag Ban',
#        'End Legal Recognition',
#        "Don't Say Gay / Forced Outing By Schools",
#        'Ban on Public Investment in ESG Funds', 'Sports Ban',
#        'Liability Law/Backdoor Ban',
#        "Don't Say Gay / Forced Outing By Schools / Trans Bathroom Ban",
#        'Online Obscenity Law', 'End Legal Recognition',
#        'Online Obscenity Law', 'Legal Discrimination in Education',
#        "Don't Say Gay / Forced Outing By Schools", 'Online Obscenity Law',
#        'DEI Ban', 'Online Obscenity Law', 'Forced Outing By Schools',
#        'Social Credit Score', 'Trans Bathroom Ban',
#        'Online Obscenity Law', 'Social Credit Score',
#        'Gender Affirming Care Ban', 'Legal Discrimination in Healthcare',
#        'End Legal Recognition',
# ...

# %%
edu = df['Bill Type'].str.contains('Education')

# %%
df[edu].value_counts('State').plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>
