# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv('https://bit.ly/anti-trans-tracker')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   State                         674 non-null    object
#  1   Number                        674 non-null    object
#  2   Summary                       673 non-null    object
#  3   Bill Type                     674 non-null    object
#  4   Date                          674 non-null    object
#  5   Status                        674 non-null    object
#  6   Youth State Risk              674 non-null    object
#  7   Adult State Risk              674 non-null    object
#  8   Notes                         365 non-null    object
#  9   URL                           674 non-null    object
#  10  Sponsors                      530 non-null    object
#  11  Calendar                      255 non-null    object
#  12  History                       526 non-null    object
#  13  Manual Status                 626 non-null    object
#  14  Change Hash                   527 non-null    object
#  15  Bill ID                       527 non-null    float64
#  16  PDF                           527 non-null    object
#  17  Bill Analysis (AI Automated)  4 non-null      object
#  18  Bill PDF                      508 non-null    object
# dtypes: float64(1), object(18)
# memory usage: 100.2+ KB

# %%
df.columns
# Out:
# Index(['State', 'Number', 'Summary', 'Bill Type', 'Date', 'Status',
#        'Youth State Risk', 'Adult State Risk', 'Notes', 'URL', 'Sponsors',
#        'Calendar', 'History', 'Manual Status', 'Change Hash', 'Bill ID', 'PDF',
#        'Bill Analysis (AI Automated)', 'Bill PDF'],
#       dtype='object')

# %%
df['Summary']
# Out:
# 0      Sex-based terms, defined;  vital statistics, r...
# 1      Crimes and offenses, further provides for obsc...
# 2      Education, instruction about gender identity a...
# 3      Consumer Protection; online distribution of ma...
# 4      Consumer protection; filter requirements on In...
#                              ...
# 669       Sex offender registration-promoting obscenity.
# 670    An act regarding compelled speech and state em...
# 671    Statute of limitations-medical procedures on m...
# 672                  Children gender change prohibition.
# 673             The equality state not equity state act.
# Name: Summary, Length: 674, dtype: object

# %%
df.shape
# Out:
# (674, 19)

# %%
df.sort_values(['Bill Type', 'State'], inplace = True)

# %%
sorted = df.sort_values(['Date'])

# %%
sorted.tail(20)
# Out:
#              State  Number                                            Summary  \
# 542             US  HJR165  Providing for congressional disapproval under ...
# 348  New Hampshire  HB1205                 Relative to women's school sports.
# 359  New Hampshire   HB619  To require a person to attain the age of major...
# 358  New Hampshire   HB396  Permitting classification of individuals based...
# 351  New Hampshire  HB1312  Requiring parental notification of student hea...
# 539             US  HB9218  To establish a clear and consistent biological...
# 546             US  SB2073  A bill to amend title 31, United States Code, ...
# 1          Alabama     HB4  Crimes and offenses, further provides for obsc...
# 551             US  SB4638  A bill to authorize appropriations for fiscal ...
# 531             US  HB8070  To authorize appropriations for fiscal year 20...
# 362  New Hampshire   SB375   Relative to biological sex in student athletics.
# 384           Ohio   HB245       Prohibits certain adult cabaret performances
# 536             US  HB8998  Making appropriations for the Department of th...
# 532             US  HB8580  Making appropriations for military constructio...
# 540             US  HB9586  To prohibit Federal funds from being used to p...
# 535             US  HB8774  Making appropriations for the Department of De...
# 534             US  HB8771  Making appropriations for the Department of St...
# 389           Ohio     HB8                  Enact the Parents' Bill of Rights
# 530             US  HB7891  To protect the safety of children on the inter...
# 438   Pennsylvania  HB2546  An Act amending the act of March 10, 1949 (P.L...
#
#                                              Bill Type       Date  \
# 542     Sports Ban / Legal Discrimination in Education  7/23/2024
# 348                                         Sports Ban  7/26/2024
# 359                          Gender Affirming Care Ban  7/26/2024
# 358                                 Trans Bathroom Ban  7/26/2024
# 351             Don't Say Gay/Forced Outing By Schools  7/26/2024
# 539  Sports Ban / Trans Bathroom Ban / End Legal Re...  7/30/2024
# 546                         KOSA-Type Social Media Law  7/31/2024
# 1                                             Book Ban   7/8/2024
# 551         Appropriations / Gender Affirming Care Ban   7/8/2024
# 531  Appropriations / Gender Affirming Care Ban / D...   7/8/2024
# 362                                         Sports Ban  9/11/2024
# 384                                           Drag Ban  9/12/2023
# 536  Appropriations / Gender Affirming Care Ban / D...  9/12/2024
# 532  Appropriations / Pride Flag Ban / Gender Affir...  9/12/2024
# 540                          Gender Affirming Care Ban  9/12/2024
# 535  Appropriations / Gender Affirming Care Ban / D...  9/12/2024
# 534  Appropriations / Gender Affirming Care Ban / D...  9/12/2024
# 389             Don't Say Gay/Forced Outing By Schools  9/13/2023
# 530                         KOSA-Type Social Media Law  9/18/2024
# 438                                            DEI Ban   9/6/2024
#
#                                                 Status Youth State Risk  \
# 542  Received in the Senate. Read twice. Placed on ...             High
# 348  Signed by Governor Sununu 07/19/2024; Chapter ...             High
# 359  Signed by Governor Sununu 07/19/2024; Chapter ...             High
# 358               Vetoed by Governor Sununu 07/19/2024             High
# 351  Signed by Governor Sununu 07/19/2024; Chapter ...             High
# 539  Referred to the House Committee on the Judiciary.             High
# 546        Message on Senate action sent to the House.             High
# 1                              Pending House Judiciary            Worst
# 551  Placed on Senate Legislative Calendar under Ge...             High
# 531                            Received in the Senate.             High
# 362  10/03/2024 10:30 am Legislative Office Buildin...             High
# 384            Referred to committee: Criminal Justice            Worst
# 536  Read twice. Placed on Senate Legislative Calen...             High
# 532  Placed on Senate Legislative Calendar under Ge...             High
# 540  Referred to the Committee on Energy and Commer...             High
# 535  Read twice. Placed on Senate Legislative Calen...             High
# 534  Read twice. Placed on Senate Legislative Calen...             High
# 389                   Referred to committee: Education            Worst
# 530    Ordered to be Reported (Amended) by Voice Vote.             High
# 438                              Referred to EDUCATION              Low
#
#     Adult State Risk                                              Notes  \
# 542             High  This is in regards to the Biden Administration...
# 348             High  A Fairness in Women's Sports Act; grades 5-12;...
# 359             High  Gender affirming genital (internal and externa...
# 358             High  Prison, Sports, Bathroom ban; last year's vers...
# 351             High  Two week notice to parents required for curric...
# 539             High  "Defining Male and Female Act of 2024"; text n...
# 546             High                 Kids Online Safety and Privacy Act
# 1              Worst  Prefiled for 2025 session; re: K12 & public li...
# 551             High  Defense Appropriations bill that includes a ba...
# 531             High  DoD appropriations omnibus bill which includes...
# 362             High  Original version used definition of "sex" from...
# 384             High  No 2024 activity shown on LegiScan as of 9/20/...
# 536             High  DoInterior appropriations which includes prohi...
# 532             High  Contains riders which ban funding GAC for vete...
# 540             High  Blocks GAC funds for those in custody of DHS o...
# 535             High  DoD appropriations omnibus bill which includes...
# 534             High  Various amendments include restrictions on usi...
# 389             High  No 2024 activity shown on LegiScan as of 9/20/...
# 530             High             Kids Online Safety Act - House Version
# 438              Low  DEI office and training ban explicitly referen...
#
#                                           URL  \
# 542  https://legiscan.com/US/bill/HJR165/2023
# 348  https://legiscan.com/NH/bill/HB1205/2024
# 359   https://legiscan.com/NH/bill/HB619/2024
# 358   https://legiscan.com/NH/bill/HB396/2024
# 351  https://legiscan.com/NH/bill/HB1312/2024
# 539  https://legiscan.com/US/bill/HB9218/2023
# 546  https://legiscan.com/US/bill/SB2073/2023
# 1       https://legiscan.com/AL/bill/HB4/2025
# 551  https://legiscan.com/US/bill/SB4638/2023
# 531  https://legiscan.com/US/bill/HB8070/2023
# 362   https://legiscan.com/NH/bill/SB375/2024
# 384   https://legiscan.com/OH/bill/HB245/2023
# 536  https://legiscan.com/US/bill/HB8998/2023
# 532  https://legiscan.com/US/bill/HB8580/2023
# 540  https://legiscan.com/US/bill/HB9586/2023
# 535  https://legiscan.com/US/bill/HB8774/2023
# 534  https://legiscan.com/US/bill/HB8771/2023
# 389     https://legiscan.com/OH/bill/HB8/2023
# 530  https://legiscan.com/US/bill/HB7891/2023
# 438  https://legiscan.com/PA/bill/HB2546/2023
#
#                                               Sponsors  \
# 542                                                NaN
# 348  Louise Andrus, Leonard Turcotte, Riche Colcomb...
# 359  Terry Roy, James Spillane, Nikki McCarter, Kev...
# 358  Jim Kofalt, Alicia Lekas, Judy Aron, Katherine...
# 351  Kristine Perez, Louise Andrus, Jim Kofalt, San...
# 539                                                NaN
# 546                                                NaN
# 1                                                  NaN
# 551                                                NaN
# 531                                                NaN
# 362  Kevin Avard, Carrie Gendreau, Ruth Ward, Willi...
# 384  Angela King, Josh Williams, Tim Barhorst, Adam...
# 536                                                NaN
# 532                                                NaN
# 540                                                NaN
# 535                                                NaN
# 534                                                NaN
# 389  D. J. Swearingen, Sara Carruthers, Cindy Abram...
# 530                                                NaN
# 438                                                NaN
#
#                                               Calendar  \
# 542                                                NaN
# 348  Hearing 2024-01-29 14:00 Legislative Office Bu...
# 359  Hearing 2023-03-07 10:00 State House Reps Hall...
# 358  Hearing 2023-01-26 16:00 Legislative Office Bu...
# 351  Hearing 2024-02-06 09:30 Legislative Office Bu...
# 539                                                NaN
# 546                                                NaN
# 1                                                  NaN
# 551                                                NaN
# 531                                                NaN
# 362  Hearing 2024-01-30 09:00 Room 101, Legislative...
# 384                  Hearing 2023-11-15 15:15 Room 121
# 536                                                NaN
# 532                                                NaN
# 540                                                NaN
# 535                                                NaN
# 534                                                NaN
# 389  Hearing 2023-03-07 16:00 Room 116, Hearing 202...
# 530                                                NaN
# 438                                                NaN
#
#                                                History     Manual Status  \
# 542                                                NaN  Pass One Chamber
# 348  H 2023-12-01 Introduced 01/03/2024 and referre...           Enacted
# 359  H 2023-01-12 Introduced (in recess of) 01/05/2...           Enacted
# 358  H 2023-01-09 Introduced (in recess of) 01/05/2...            Vetoed
# 351  H 2023-12-06 Introduced 01/03/2024 and referre...           Enacted
# 539                                                NaN               NaN
# 546                                                NaN  Pass One Chamber
# 1                                                  NaN         Roll Over
# 551                                                NaN    Pass Committee
# 531                                                NaN  Pass One Chamber
# 362  S 2023-12-12 To Be Introduced 01/03/2024 and R...            Failed
# 384  H 2023-07-17 Introduced, H 2023-09-12 Referred...               NaN
# 536                                                NaN  Pass One Chamber
# 532                                                NaN  Pass One Chamber
# 540                                                NaN               NaN
# 535                                                NaN  Pass One Chamber
# 534                                                NaN  Pass One Chamber
# 389  H 2023-02-15 Introduced, H 2023-02-16 Referred...  Pass One Chamber
# 530                                                NaN    Pass Committee
# 438                                                NaN               NaN
#
#                           Change Hash    Bill ID  \
# 542                               NaN        NaN
# 348  62262783f3496d5e636ebbdb3fa1e3e1  1785354.0
# 359  cd9250d226ff19cd7773181151b1df14  1793146.0
# 358  90afadc3ce172bcb30049077bb415bbc  1793186.0
# 351  9e2c38e4aa1a339e21ef97d72b559d2e  1793411.0
# 539                               NaN        NaN
# 546                               NaN        NaN
# 1                                 NaN        NaN
# 551                               NaN        NaN
# 531                               NaN        NaN
# 362  799c06ffcff0a1186f561f9c9f4ec2fb  1793318.0
# 384  3c1d1c1e938075b26a652d56b8b17845  1774630.0
# 536                               NaN        NaN
# 532                               NaN        NaN
# 540                               NaN        NaN
# 535                               NaN        NaN
# 534                               NaN        NaN
# 389  cd75f02d462e332cd905ce2d3e8d12b3  1711236.0
# 530                               NaN        NaN
# 438                               NaN        NaN
#
#                                                    PDF  \
# 542                                                NaN
# 348  https://gencourt.state.nh.us/bill_status/legac...
# 359  https://gencourt.state.nh.us/bill_status/legac...
# 358  https://gencourt.state.nh.us/bill_status/legac...
# 351  https://gencourt.state.nh.us/bill_status/legac...
# 539                                                NaN
# 546                                                NaN
# 1                                                  NaN
# 551                                                NaN
# 531                                                NaN
# 362  https://gencourt.state.nh.us/bill_status/legac...
# 384  https://search-prod.lis.state.oh.us/solarapi/v...
# 536                                                NaN
# 532                                                NaN
# 540                                                NaN
# 535                                                NaN
# 534                                                NaN
# 389  https://search-prod.lis.state.oh.us/solarapi/v...
# 530                                                NaN
# 438                                                NaN
#
#     Bill Analysis (AI Automated)  \
# 542                          NaN
# 348                          NaN
# 359                          NaN
# 358                          NaN
# 351                          NaN
# 539                          NaN
# 546                          NaN
# 1                            NaN
# 551                          NaN
# 531                          NaN
# 362                          NaN
# 384                          NaN
# 536                          NaN
# 532                          NaN
# 540                          NaN
# 535                          NaN
# 534                          NaN
# 389                          NaN
# 530                          NaN
# 438                          NaN
#
#                                               Bill PDF
# 542                                                NaN
# 348  https://drive.google.com/open?id=18tA4rt6rcZwl...
# 359  https://drive.google.com/open?id=1yhMCQWJ0mtuz...
# 358  https://drive.google.com/open?id=12qR0RPo6zbL0...
# 351  https://drive.google.com/open?id=1uA6bf3gc692g...
# 539                                                NaN
# 546                                                NaN
# 1                                                  NaN
# 551                                                NaN
# 531                                                NaN
# 362  https://drive.google.com/open?id=1BtSCK9w_aHiM...
# 384  https://drive.google.com/open?id=1jLosEjD-e-tK...
# 536                                                NaN
# 532                                                NaN
# 540                                                NaN
# 535                                                NaN
# 534                                                NaN
# 389  https://drive.google.com/open?id=12BHJQHSv0X4i...
# 530                                                NaN
# 438                                                NaN

# %%
df.value_counts('Bill Type')
# Out:
# Bill Type
# Online Obscenity Law                            86
# Gender Affirming Care Ban                       61
# Book Ban                                        51
# Sports Ban                                      43
# DEI Ban                                         40
#                                                 ..
# Bathroom Ban/Prison Placement Ban                1
# Omnibus Anti-trans Bill                          1
# Ban On Public Investment in ESG Funds            1
# Drag Ban/Book Ban                                1
# Forced Outing By Schools/ Trans Bathroom Ban     1
# Name: count, Length: 83, dtype: int64

# %%
ny = df['State'] == 'New York'

# %%
pd.set_option('display.max_colwidth', None)

# %%
df[ny]['Summary']
# Out:
# 379    Expands insurance coverage for in vitro fertilization; includes coverage under individual policies; provides coverage for three complete oocyte retrievals and in vitro fertilization with unlimited embryo transfers.
# 381                                                                                              Removes restrictions of three-cycle coverage for in vitro fertilization; mandates individual insurance coverage of in vitro.
# 382    Expands insurance coverage for in vitro fertilization; includes coverage under individual policies; provides coverage for three complete oocyte retrievals and in vitro fertilization with unlimited embryo transfers.
# 378                                                                                                                                         Protects women's sports in middle school and high school from unfair competition.
# 380                                                                                                                                         Protects women's sports in middle school and high school from unfair competition.
# Name: Summary, dtype: object

# %%
df['Bill Type'].str.contains('Book')
# Out:
# 169    False
# 171    False
# 179    False
# 187    False
# 283    False
#        ...
# 245    False
# 266    False
# 117    False
# 487    False
# 503    False
# Name: Bill Type, Length: 674, dtype: bool

# %%
books = df['Bill Type'].str.contains('Book')

# %%
type(books)
# Out:
# pandas.core.series.Series

# %%
df[books].value_counts('State')
# Out:
# State
# Missouri          6
# West Virginia     4
# Idaho             4
# Tennessee         4
# Wyoming           3
# New Hampshire     3
# Maryland          3
# Mississippi       2
# South Carolina    2
# Oklahoma          2
# Alabama           2
# Louisiana         2
# Kentucky          2
# Kansas            2
# Georgia           2
# Nebraska          2
# California        1
# Ohio              1
# Pennsylvania      1
# Iowa              1
# South Dakota      1
# Indiana           1
# US                1
# Utah              1
# Virginia          1
# Name: count, dtype: int64

# %%
df.plot()
# Out:
# <Axes: >

# %%
# method chaining

# nlargest()

fig = df.value_counts('Bill Type').plot(kind='pie', xlabel='Number of Bills', title='Most Frequent Categories for Bills').get_figure()

# %%
fig.savefig('test.png')

# %%
df.columns
# Out:
# Index(['State', 'Number', 'Summary', 'Bill Type', 'Date', 'Status',
#        'Youth State Risk', 'Adult State Risk', 'Notes', 'URL', 'Sponsors',
#        'Calendar', 'History', 'Manual Status', 'Change Hash', 'Bill ID', 'PDF',
#        'Bill Analysis (AI Automated)', 'Bill PDF'],
#       dtype='object')

# %%
df.value_counts('Adult State Risk').plot(kind='bar')
# Out:
# <Axes: xlabel='Adult State Risk'>

# %%
# pd.to_datetime('2018-10-26 12:00:00.0000000011',format='%Y-%m-%d %H:%M:%S.%f')

pd.to_datetime(df['Date'], format='%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 3
#       1 # pd.to_datetime('2018-10-26 12:00:00.0000000011',format='%Y-%m-%d %H:%M:%S.%f')
# ----> 3 pd.to_datetime(df['Date'], format='%m/%d/%Y')
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# --> 247     cache_dates = convert_listlike(unique_dates, format)
#     248     # GH#45319
#     249     try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "45546" doesn't match format "%m/%d/%Y", at position 89. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
corrupt = df['Date'] == '45546'

# %%
df[corrupt]
# Out:
#              State  Number                                    Summary  \
# 347  New Hampshire  HB1185  Relative to sexual education instruction.
#
#                                   Bill Type   Date  \
# 347  Don't Say Gay/Forced Outing By Schools  45546
#
#                                                                          Status  \
# 347  Executive Session: 10/03/2024 10:30 am Legislative Office Building 205-207
#
#     Youth State Risk Adult State Risk Notes  \
# 347             High             High   NaN
#
#                                           URL  \
# 347  https://legiscan.com/NH/bill/HB1185/2024
#
#                                                                                                           Sponsors  \
# 347  Karen Reid, Carroll Brown, John Sellers, Sheila Seidel, Lisa Mazur, Riche Colcombe, Kevin Avard, Keith Murphy
#
#                                                                                                                        Calendar  \
# 347  Hearing 2024-02-05 09:30 Legislative Office Building 205-207, Hearing 2024-02-13 09:45 Legislative Office Building 205-207
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                              History  \
# 347  H 2023-12-01 Introduced 01/03/2024 and referred to Education, H 2024-01-31 Public Hearing: 02/05/2024 09:30 am Legislative Office Building 205-207, H 2024-02-05 Executive Session: 02/13/2024 09:45 am Legislative Office Building 205-207, H 2024-02-20 Committee Report: Refer for Interim Study 02/13/2024 (Vote 20-0; Consent Calendar) House Calendar 9 P. 6, H 2024-03-07 Refer for Interim Study: Motion Adopted Voice Vote 03/07/2024 House Journal  7
#
#     Manual Status                       Change Hash    Bill ID  \
# 347        Failed  733ec0151d82cd52c33097bf0ac2284d  1785520.0
#
#                                                                                                      PDF  \
# 347  https://gencourt.state.nh.us/bill_status/legacy/bs2016/billText.aspx?sy=2024&id=1182&txtFormat=html
#
#     Bill Analysis (AI Automated)  \
# 347                          NaN
#
#                                                                Bill PDF
# 347  https://drive.google.com/open?id=1qS2XorMC4SIUPRUMeQ1BGPKI79ziwxIF

# %%
for i in df['Date']:
    if i == 45546:
        i.replace(i, '10/03/2024')

# %%
pd.to_datetime(df['Date'], format='%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 pd.to_datetime(df['Date'], format='%m/%d/%Y')
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# --> 247     cache_dates = convert_listlike(unique_dates, format)
#     248     # GH#45319
#     249     try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "45546" doesn't match format "%m/%d/%Y", at position 89. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
df.iloc[89]
# Out:
# State                                                                                                                                                                                         Ohio
# Number                                                                                                                                                                                       HB556
# Summary                         To amend sections 2907.32 and 2907.35 of the Revised Code to create criminal liability for certain teachers and librarians for the offense of pandering obscenity.
# Bill Type                                                                                                                                 Book Ban / Legal Discrimination in Education / Obscenity
# Date                                                                                                                                                                                     5/21/2024
# Status                                                                                                                                                     Referred to committee: Criminal Justice
# Youth State Risk                                                                                                                                                                             Worst
# Adult State Risk                                                                                                                                                                              High
# Notes                                                                                    Criminal obscenity ban for teachers and school librarians for material not used in bio or health classes.
# URL                                                                                                                                                        https://legiscan.com/OH/bill/HB556/2023
# Sponsors                                                                                                                                                                                       NaN
# Calendar                                                                                                                                                                                       NaN
# History                                                                                                                                                                                        NaN
# Manual Status                                                                                                                                                                                  NaN
# Change Hash                                                                                                                                                                                    NaN
# Bill ID                                                                                                                                                                                        NaN
# PDF                                                                                                                                                                                            NaN
# Bill Analysis (AI Automated)                                                                                                                                                                   NaN
# Bill PDF                                                                                                                                                                                       NaN
# Name: 387, dtype: object
