# %%
import pandas as pd

# %%
df = pd.read_csv('https://bit.ly/met_woman')

# %%
df
# Out:
#      Unnamed: 0  objectID  isHighlight    accessionNumber  accessionYear  \
# 0             0  483873.0          0.0         1984.613.2         1984.0
# 1             1  207162.0          0.0        1982.60.281         1982.0
# 2             2  247582.0          0.0            06.1169         1906.0
# 3             3  283274.0          0.0       2005.100.206         1999.0
# 4             4  483877.0          0.0         1984.613.6         1984.0
# ..          ...       ...          ...                ...            ...
# 495         495  202972.0          0.0             63.197         1963.0
# 496         496  338096.0          0.0            66.93.2         1966.0
# 497         497  252375.0          0.0          26.31.453         1926.0
# 498         498  545150.0          0.0           25.3.253         1925.0
# 499         499  207191.0          0.0  1982.60.311, .312         1982.0
#
#      isPublicDomain                                       primaryImage  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 59 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             500 non-null    int64
#  1   objectID               492 non-null    float64
#  2   isHighlight            492 non-null    float64
#  3   accessionNumber        492 non-null    object
#  4   accessionYear          489 non-null    float64
#  5   isPublicDomain         492 non-null    float64
#  6   primaryImage           415 non-null    object
#  7   primaryImageSmall      415 non-null    object
#  8   additionalImages       492 non-null    object
#  9   constituents           129 non-null    object
#  10  department             492 non-null    object
#  11  objectName             491 non-null    object
#  12  title                  492 non-null    object
#  13  culture                283 non-null    object
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  objectID  isHighlight    accessionNumber  accessionYear  \
# 495         495  202972.0          0.0             63.197         1963.0
# 496         496  338096.0          0.0            66.93.2         1966.0
# 497         497  252375.0          0.0          26.31.453         1926.0
# 498         498  545150.0          0.0           25.3.253         1925.0
# 499         499  207191.0          0.0  1982.60.311, .312         1982.0
#
#      isPublicDomain                                       primaryImage  \
# 495             1.0  https://images.metmuseum.org/CRDImages/es/orig...
# 496             1.0  https://images.metmuseum.org/CRDImages/dp/orig...
# 497             0.0                                                NaN
# 498             1.0  https://images.metmuseum.org/CRDImages/eg/orig...
# 499             1.0  https://images.metmuseum.org/CRDImages/es/orig...
#
#                                      primaryImageSmall  \
# ...

# %%
df.shape
# Out:
# (500, 59)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'objectID', 'isHighlight', 'accessionNumber',
#        'accessionYear', 'isPublicDomain', 'primaryImage', 'primaryImageSmall',
#        'additionalImages', 'constituents', 'department', 'objectName', 'title',
#        'culture', 'period', 'dynasty', 'reign', 'portfolio', 'artistRole',
#        'artistPrefix', 'artistDisplayName', 'artistDisplayBio', 'artistSuffix',
#        'artistAlphaSort', 'artistNationality', 'artistBeginDate',
#        'artistEndDate', 'artistGender', 'artistWikidata_URL', 'artistULAN_URL',
#        'objectDate', 'objectBeginDate', 'objectEndDate', 'medium',
#        'dimensions', 'measurements', 'creditLine', 'geographyType', 'city',
#        'state', 'county', 'country', 'region', 'subregion', 'locale', 'locus',
#        'excavation', 'river', 'classification', 'rightsAndReproduction',
#        'linkResource', 'metadataDate', 'repository', 'objectURL', 'tags',
#        'objectWikidata_URL', 'isTimelineWork', 'GalleryNumber', 'message'],
# ...

# %%
df.title
# Out:
# 0                                                  Woman
# 1                                                  Woman
# 2                        Terracotta lekythos (oil flask)
# 3                                                  Woman
# 4                                                  Woman
#                              ...
# 495                          Abduction of a Sabine Woman
# 496                Susannah and the Elders before Daniel
# 497    Terracotta alabastron (perfume vase) in the fo...
# 498                                            Sa Amulet
# 499                                      The Thrown Kiss
# Name: title, Length: 500, dtype: object

# %%
type(df['title'])
# Out:
# pandas.core.series.Series

# %%
df['title'].values
# Out:
# array(['Woman', 'Woman', 'Terracotta lekythos (oil flask)', 'Woman',
#        'Woman', nan, 'Woman', 'Woman', 'Woman', 'Woman', nan, 'Woman',
#        'Woman', 'Woman', nan, 'Woman', 'Woman', 'Woman', 'Woman', 'Woman',
#        'Woman', 'Woman', 'Woman Having Her Hair Combed', 'Standing Woman',
#        nan,
#        'Cosmetic Spoon in the Shape of Swimming Woman Holding a Dish',
#        'Cartonnage of a Woman',
#        'Marble grave stele of a young woman and servant',
#        'Woman with a Cat', 'Mourning Woman',
#        'Young Man and Woman in an Inn', 'Woman Stretching',
#        'Bronze mirror with a support in the form of a draped woman',
#        'Terracotta head of a woman', 'Figurine of a Seated Woman',
#        'A Woman Seated beside a Vase of Flowers (Madame Paul Valpinçon?)',
#        'Woman Grinding Coffee',
#        'Portrait of a Woman with a Man at a Casement',
#        'Shroud of a Woman Wearing a Fringed Tunic', 'Woman with a Pink',
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0       objectID  isHighlight  accessionYear  isPublicDomain  \
# count  500.000000     492.000000   492.000000     489.000000      492.000000
# mean   249.500000  338124.420732     0.075203    1935.578732        0.845528
# std    144.481833  150547.306742     0.263987      37.739216        0.361768
# min      0.000000   10112.000000     0.000000    1871.000000        0.000000
# 25%    124.750000  247556.750000     0.000000    1910.000000        1.000000
# 50%    249.500000  253507.000000     0.000000    1926.000000        1.000000
# 75%    374.250000  469534.000000     0.000000    1966.000000        1.000000
# max    499.000000  897321.000000     1.000000    2023.000000        1.000000
#
#        portfolio  objectBeginDate  objectEndDate  county  river  linkResource  \
# count        0.0       492.000000     492.000000     0.0    0.0           0.0
# mean         NaN        25.123984     117.554878     NaN    NaN           NaN
# ...

# %%
df[200:205]
# Out:
#      Unnamed: 0  objectID  isHighlight accessionNumber  accessionYear  \
# 200         200  251510.0          0.0        24.97.84         1924.0
# 201         201  255434.0          0.0    1972.118.123         1972.0
# 202         202  254761.0          0.0         53.5.36         1953.0
# 203         203  248793.0          0.0       13.227.13         1913.0
# 204         204  251274.0          0.0         23.73.4         1923.0
#
#      isPublicDomain                                       primaryImage  \
# 200             1.0  https://images.metmuseum.org/CRDImages/gr/orig...
# 201             1.0  https://images.metmuseum.org/CRDImages/gr/orig...
# 202             1.0  https://images.metmuseum.org/CRDImages/gr/orig...
# 203             1.0  https://images.metmuseum.org/CRDImages/gr/orig...
# 204             1.0  https://images.metmuseum.org/CRDImages/gr/orig...
#
#                                      primaryImageSmall additionalImages  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'objectID', 'isHighlight', 'accessionNumber',
#        'accessionYear', 'isPublicDomain', 'primaryImage', 'primaryImageSmall',
#        'additionalImages', 'constituents', 'department', 'objectName', 'title',
#        'culture', 'period', 'dynasty', 'reign', 'portfolio', 'artistRole',
#        'artistPrefix', 'artistDisplayName', 'artistDisplayBio', 'artistSuffix',
#        'artistAlphaSort', 'artistNationality', 'artistBeginDate',
#        'artistEndDate', 'artistGender', 'artistWikidata_URL', 'artistULAN_URL',
#        'objectDate', 'objectBeginDate', 'objectEndDate', 'medium',
#        'dimensions', 'measurements', 'creditLine', 'geographyType', 'city',
#        'state', 'county', 'country', 'region', 'subregion', 'locale', 'locus',
#        'excavation', 'river', 'classification', 'rightsAndReproduction',
#        'linkResource', 'metadataDate', 'repository', 'objectURL', 'tags',
#        'objectWikidata_URL', 'isTimelineWork', 'GalleryNumber', 'message'],
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 59 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             500 non-null    int64
#  1   objectID               492 non-null    float64
#  2   isHighlight            492 non-null    float64
#  3   accessionNumber        492 non-null    object
#  4   accessionYear          489 non-null    float64
#  5   isPublicDomain         492 non-null    float64
#  6   primaryImage           415 non-null    object
#  7   primaryImageSmall      415 non-null    object
#  8   additionalImages       492 non-null    object
#  9   constituents           129 non-null    object
#  10  department             492 non-null    object
#  11  objectName             491 non-null    object
#  12  title                  492 non-null    object
#  13  culture                283 non-null    object
# ...

# %%
cultures = df['culture'].values

# %%
type(cultures)
# Out:
# numpy.ndarray

# %%
type(cultures)
# Out:
# numpy.ndarray

# %%
cultures
# Out:
# array([nan, nan, 'Greek, Attic', nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, 'Greek, Attic', nan, 'South Netherlandish', nan,
#        nan, 'Greek, Argive', 'Greek, South Italian, Tarentine', nan, nan,
#        nan, nan, nan, nan, 'Greek', nan, nan, 'Greek, Attic',
#        'Greek, perhaps from Asia Minor', 'Etruscan', nan, 'East Greek',
#        'Roman', nan, nan, 'Greek, Argive', nan, nan, nan, 'Etruscan', nan,
#        'Cycladic', 'Cycladic', nan,
#        'Greek, probably West Greek, possibly Centuripe', nan, nan, nan,
#        nan, nan, nan, 'Byzantine (Egypt)', nan, nan, nan, nan, 'Greek',
#        'Etruscan', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, 'Greek, probably Boeotian', nan,
#        nan, nan, nan, nan, nan, nan, nan, 'Greek, Cretan', nan,
#        'Byzantine', 'North French or South Netherlandish',
# ...

# %%
## write a loop that prints out all items that have "Greek" in the culture
## str()

for i in cultures:
    if 'Greek' in str(i):
        print(i)
# Out:
# Greek, Attic
# Greek, Attic
# Greek, Argive
# Greek, South Italian, Tarentine
# Greek
# Greek, Attic
# Greek, perhaps from Asia Minor
# East Greek
# Greek, Argive
# Greek, probably West Greek, possibly Centuripe
# Greek
# Greek, probably Boeotian
# Greek, Cretan
# East Greek
# Greek
# East Greek
# Greek, Boeotian
# Greek, Attic
# Greek, Attic (?)
# Greek, South Italian, Tarentine
# Greek
# Greek
# Greek, Boeotian
# Greek, Asia Minor, Smyrna
# Greek, Corinthian
# Greek, South Italian, Tarentine
# Greek, Attic
# Greek, Boeotian
# Greek
# Greek, Corinthian
# Greek
# Greek
# Greek, South Italian, Tarentine
# Greek, South Italian, Tarentine
# Greek, South Italian, Tarentine
# Greek, Boeotian
# Greek, South Italian (?)
# Greek, Attic
# Greek
# Greek, Attic
# Greek, South Italian, Tarentine
# Greek, Attic
# Greek, South Italian, Tarentine
# Greek, Attic
# Greek, Pontus
# Greek, Boeotian
# Greek
# Greek, Cretan
# East Greek
# Greek, Cretan
# Greek, Corinthian
# Greek, Cypriot
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'objectID', 'isHighlight', 'accessionNumber',
#        'accessionYear', 'isPublicDomain', 'primaryImage', 'primaryImageSmall',
#        'additionalImages', 'constituents', 'department', 'objectName', 'title',
#        'culture', 'period', 'dynasty', 'reign', 'portfolio', 'artistRole',
#        'artistPrefix', 'artistDisplayName', 'artistDisplayBio', 'artistSuffix',
#        'artistAlphaSort', 'artistNationality', 'artistBeginDate',
#        'artistEndDate', 'artistGender', 'artistWikidata_URL', 'artistULAN_URL',
#        'objectDate', 'objectBeginDate', 'objectEndDate', 'medium',
#        'dimensions', 'measurements', 'creditLine', 'geographyType', 'city',
#        'state', 'county', 'country', 'region', 'subregion', 'locale', 'locus',
#        'excavation', 'river', 'classification', 'rightsAndReproduction',
#        'linkResource', 'metadataDate', 'repository', 'objectURL', 'tags',
#        'objectWikidata_URL', 'isTimelineWork', 'GalleryNumber', 'message'],
# ...

# %%
df.value_counts('culture')
# Out:
# culture
# Roman                                             33
# Greek                                             28
# Greek, South Italian, Tarentine                   23
# Cypriot                                           21
# Greek, Attic                                      20
# Greek, Boeotian                                   18
# East Greek                                        17
# Etruscan                                          13
# Cycladic                                           9
# Greek, Cretan                                      9
# American                                           9
# Greek, Cypriot                                     7
# Greek, probably Attic                              6
# Helladic, Mycenaean                                5
# Greek or Roman                                     4
# Greek, Corinthian                                  4
# Egyptian (?)                                       3
# Byzantine                                          3
# ...

# %%
df.sort_values('accessionYear')
# Out:
#      Unnamed: 0  objectID  isHighlight accessionNumber  accessionYear  \
# 467         467  437759.0          0.0           71.34         1871.0
# 110         110  244801.0          0.0        74.57.20         1874.0
# 341         341  244734.0          0.0      74.51.5859         1874.0
# 217         217  241279.0          0.0      74.51.1724         1874.0
# 334         334  241063.0          0.0      74.51.1507         1874.0
# ..          ...       ...          ...             ...            ...
# 353         353       NaN          NaN             NaN            NaN
# 356         356       NaN          NaN             NaN            NaN
# 367         367  256758.0          0.0           X.125            NaN
# 427         427       NaN          NaN             NaN            NaN
# 472         472       NaN          NaN             NaN            NaN
#
#      isPublicDomain                                       primaryImage  \
# ...

# %%
new = df['title'] == 'Woman'

# %%
df[new]
# Out:
#     Unnamed: 0  objectID  isHighlight accessionNumber  accessionYear  \
# 0            0  483873.0          0.0      1984.613.2         1984.0
# 1            1  207162.0          0.0     1982.60.281         1982.0
# 3            3  283274.0          0.0    2005.100.206         1999.0
# 4            4  483877.0          0.0      1984.613.6         1984.0
# 6            6  494305.0          0.0      2007.247.5         2007.0
# 7            7  481438.0          0.0      1975.189.6         1975.0
# 8            8  374147.0          0.0       43.33.754         1943.0
# 9            9  515811.0          0.0         2002.59         2002.0
# 11          11  489510.0          0.0         66.75.2         1966.0
# 12          12  492892.0          0.0    2002.456.122         2002.0
# 13          13  486510.0          0.0        1994.592         1994.0
# 15          15  204181.0          0.0       64.164.80         1964.0
# 16          16  205376.0          0.0    1971.180.184         1971.0
# ...

# %%
early = df['accessionYear'] < 1900

# %%
df[early]
# Out:
#      Unnamed: 0  objectID  isHighlight accessionNumber  accessionYear  \
# 37           37  436896.0          1.0        89.15.19         1889.0
# 66           66  437881.0          1.0        89.15.21         1889.0
# 76           76  555567.0          0.0        89.2.217         1889.0
# 93           93  568194.0          0.0         90.6.96         1890.0
# 95           95  435711.0          0.0        87.15.97         1887.0
# 110         110  244801.0          0.0        74.57.20         1874.0
# 134         134  241071.0          0.0      74.51.1515         1874.0
# 143         143  245538.0          0.0       89.2.2141         1889.0
# 155         155  241295.0          0.0      74.51.1740         1874.0
# 157         157  246283.0          0.0        96.9.260         1896.0
# 163         163  246746.0          0.0         98.8.34         1898.0
# 164         164  246747.0          0.0         98.8.35         1898.0
# ...

# %%
df[early].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 37 to 476
# Data columns (total 59 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             59 non-null     int64
#  1   objectID               59 non-null     float64
#  2   isHighlight            59 non-null     float64
#  3   accessionNumber        59 non-null     object
#  4   accessionYear          59 non-null     float64
#  5   isPublicDomain         59 non-null     float64
#  6   primaryImage           58 non-null     object
#  7   primaryImageSmall      58 non-null     object
#  8   additionalImages       59 non-null     object
#  9   constituents           4 non-null      object
#  10  department             59 non-null     object
#  11  objectName             59 non-null     object
#  12  title                  59 non-null     object
#  13  culture                51 non-null     object
# ...

# %%
df[early].shape
# Out:
# (59, 59)

# %%
culture = df[early]['culture']

# %%
culture.value_counts()
# Out:
# culture
# Cypriot                          20
# Greek, Cypriot                    7
# Etruscan                          5
# Greek, Asia Minor, Smyrna         3
# Egyptian (?)                      3
# Greek                             2
# Roman, Egyptian                   2
# Greek or Roman                    2
# Greek, Attic (?)                  1
# Greek, Asia Minor, Smyrna ?       1
# Roman, Cypriot                    1
# Italic                            1
# Greek, Asia Minor, Myrina (?)     1
# Parthian                          1
# Helladic, Mycenaean               1
# Name: count, dtype: int64

# %%
late = df['accessionYear'] > 2000

# %%
df[late]['culture'].value_counts()
# Out:
# culture
# Greek               2
# Roman               1
# Japan               1
# India (Kausambi)    1
# Central Italian     1
# American            1
# Name: count, dtype: int64

# %%
## depending on your data type, create a dataframe, bs4 soup, or list/strings.
## spend some time exploring your dataset with relevant methods from those libraries

## while you're exploring, think about
## - what is the data you want to extract from this dataset?
## - what would you like to do with that data?
